# %%
import itertools
import json
import logging
import os
import pickle
import unittest
from contextlib import contextmanager
from operator import itemgetter
from random import sample

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import pymatgen
from pymatgen.ext.matproj import MPRester
from pymatgen.core import Structure
from pandas.testing import assert_frame_equal, assert_series_equal
from pymatgen.analysis.structure_prediction.substitution_probability import SubstitutionProbability
from pymatgen.analysis.local_env import CrystalNN


import smact
from smact import Species
from smact.structure_prediction import prediction, database, mutation, probability_models, structure, utilities
from smact.structure_prediction.database import StructureDB
from smact.structure_prediction.mutation import CationMutator
from smact.structure_prediction.prediction import StructurePredictor
from smact.structure_prediction.structure import SmactStructure
from smact.structure_prediction.utilities import parse_spec, unparse_spec
from pymatgen.analysis import structure_matcher
import smact
from pymatgen.ext.matproj import MPRester
from pymatgen.core import Composition
import pandas as pd

from smact import Element,element_dictionary, ordered_elements, neutral_ratios
from smact.screening import smact_filter, pauling_test

from datetime import datetime
from pathos.multiprocessing import ProcessPool as Pool

m = MPRester("Z51OJasyeWwk4pci")

# %%
#query the MP database for binary materials with 1:1 stoichiometry
anon_formula = {'A':1, 'B':1}
binary = m.query(criteria = {'anonymous_formula':anon_formula, 'icsd_ids':{'$gte':0}}, properties = ['pretty_formula', 'material_id', 'spacegroup.symbol', 'spacegroup.crystal_system', 'icsd_ids', 'e_above_hull', 'band_gap', 'structure'])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2201/2201 [00:08<00:00, 267.13it/s]

# %%
binary_df = pd.DataFrame(binary)
binary_df = binary_df.sort_values(['pretty_formula', 'e_above_hull'])
binary_df = binary_df.reset_index(drop = True)
binary_df = binary_df.drop_duplicates('pretty_formula', keep = 'first').reset_index(drop=True)
binary_data = binary_df.to_dict('records')

# %%
SM=structure_matcher.StructureMatcher(attempt_supercell=True)

# %%
rock_salt = m.query('mp-22862', properties=['pretty_formula', 'material_id', 'spacegroup.symbol', 'spacegroup.crystal_system', 'icsd_ids', 'e_above_hull', 'band_gap', 'structure'])
rock_salt_structure = rock_salt[0]['structure']

# %%
fitted_data = []
for i in binary_data:
    if SM.fit_anonymous(i['structure'],rock_salt_structure):
        fitted_data.append(i)
print(len(fitted_data))
# Out:
# 299

# %%
cscl = m.query('mp-22865', properties=['pretty_formula', 'material_id', 'spacegroup.symbol', 'spacegroup.crystal_system', 'icsd_ids', 'e_above_hull', 'band_gap', 'structure'])
cscl_structure = cscl[0]['structure']

# %%
for i in binary_data:
    if SM.fit_anonymous(i['structure'],cscl_structure):
        fitted_data.append(i)
print(len(fitted_data))
# Out:
# 618

# %%
sphalerite = m.query('mp-10695', properties=['pretty_formula', 'material_id', 'spacegroup.symbol', 'spacegroup.crystal_system', 'icsd_ids', 'e_above_hull', 'band_gap', 'structure'])
sphalerite_structure = sphalerite[0]['structure']

# %%
for i in binary_data:
    if SM.fit_anonymous(i['structure'],sphalerite_structure):
        fitted_data.append(i)
print(len(fitted_data))
# Out:
# 677

# %%
wurtzite = m.query('mp-560588', properties=['pretty_formula', 'material_id', 'spacegroup.symbol', 'spacegroup.crystal_system', 'icsd_ids', 'e_above_hull', 'band_gap', 'structure'])
wurtzite_structure = wurtzite[0]['structure']

# %%
for i in binary_data:
    if SM.fit_anonymous(i['structure'],wurtzite_structure):
        fitted_data.append(i)
print(len(fitted_data))
# Out:
# 690

# %%
fitted_data
# Out:
# [{'pretty_formula': 'AgBr',
#   'material_id': 'mp-23231',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [56548, 56547, 65061, 53850, 56546, 52246, 65062, 157536],
#   'e_above_hull': 0.03729415000000014,
#   'band_gap': 0.7946,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.1377258397810746 4.1377258397810746 4.1377258397810746
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 50.0922035521385
#         A : 0.0 2.925814 2.925814
#         B : 2.925814 0.0 2.925814
#         C : 2.925814 2.925814 0.0
#       pbc : True True True
#   PeriodicSite: Ag (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Br (2.9258, 2.9258, 2.9258) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'AgC',
#   'material_id': 'mp-1008653',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [183175],
#   'e_above_hull': 2.235510398333333,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.300603334737757 3.300603334737757 3.300603334737757
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 25.425236687373022
#         A : 0.0 2.333879 2.333879
#         B : 2.333879 0.0 2.333879
#         C : 2.333879 2.333879 0.0
#       pbc : True True True
#   PeriodicSite: Ag (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: C (2.3339, 2.3339, 2.3339) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'AgCl',
#   'material_id': 'mp-22922',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [56540, 56539, 157535, 56538, 64734],
#   'e_above_hull': 0.0,
#   'band_gap': 1.2003,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.9756343381161203 3.9756343381161203 3.9756343381161203
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 44.4328633677782
#         A : 0.0 2.811198 2.811198
#         B : 2.811198 0.0 2.811198
#         C : 2.811198 2.811198 0.0
#       pbc : True True True
#   PeriodicSite: Ag (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Cl (2.8112, 2.8112, 2.8112) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'AgF',
#   'material_id': 'mp-7592',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [18008],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.556249306194379 3.556249306194379 3.556249306194379
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 31.802524744424137
#         A : 0.0 2.514648 2.514648
#         B : 2.514648 0.0 2.514648
#         C : 2.514648 2.514648 0.0
#       pbc : True True True
#   PeriodicSite: Ag (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: F (2.5146, 2.5146, 2.5146) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'AgN',
#   'material_id': 'mp-1056955',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [167858, 185555, 183195],
#   'e_above_hull': 1.4081794221433332,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.264118039042093 3.264118039042093 3.264118039042093
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 24.59136120734822
#         A : 0.0 2.30808 2.30808
#         B : 2.30808 0.0 2.30808
#         C : 2.30808 2.30808 0.0
#       pbc : True True True
#   PeriodicSite: Ag (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: N (2.3081, 2.3081, 2.3081) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'AlO',
#   'material_id': 'mp-8023',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [28920],
#   'e_above_hull': 1.3033435358333394,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.165384719185016 3.165384719185016 3.165384719185016
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 22.426655230978525
#         A : 0.0 2.238265 2.238265
#         B : 2.238265 0.0 2.238265
#         C : 2.238265 2.238265 0.0
#       pbc : True True True
#   PeriodicSite: Al (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: O (2.2383, 2.2383, 2.2383) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'AuN',
#   'material_id': 'mp-1008610',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [167866],
#   'e_above_hull': 1.4987504938100003,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.302052903639189 3.302052903639189 3.302052903639189
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 25.458750397514386
#         A : 0.0 2.334904 2.334904
#         B : 2.334904 0.0 2.334904
#         C : 2.334904 2.334904 0.0
#       pbc : True True True
#   PeriodicSite: Au (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: N (2.3349, 2.3349, 2.3349) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'BaN',
#   'material_id': 'mp-1057758',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [158969],
#   'e_above_hull': 0.5190953799999996,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.04817783701161 4.04817783701161 4.04817783701161
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 46.90981830124329
#         A : 0.0 2.862494 2.862494
#         B : 2.862494 0.0 2.862494
#         C : 2.862494 2.862494 0.0
#       pbc : True True True
#   PeriodicSite: Ba (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: N (2.8625, 2.8625, 2.8625) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'BaO',
#   'material_id': 'mp-1342',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [616005, 180199, 26961, 181199, 58663, 616004, 52278],
#   'e_above_hull': 0.0,
#   'band_gap': 2.2561,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.9703225519758467 3.9703225519758467 3.9703225519758467
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 44.25500294484119
#         A : 0.0 2.807442 2.807442
#         B : 2.807442 0.0 2.807442
#         C : 2.807442 2.807442 0.0
#       pbc : True True True
#   PeriodicSite: Ba (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: O (2.8074, 2.8074, 2.8074) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'BaS',
#   'material_id': 'mp-1500',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [616052, 616056, 616053, 30240, 616059, 52690, 53942],
#   'e_above_hull': 0.0,
#   'band_gap': 2.2091000000000003,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.56594546382696 4.56594546382696 4.56594546382696
#    angles : 59.99999999999999 59.99999999999999 59.99999999999999
#    volume : 67.30962359628131
#         A : 0.0 3.228611 3.228611
#         B : 3.228611 0.0 3.228611
#         C : 3.228611 3.228611 0.0
#       pbc : True True True
#   PeriodicSite: Ba (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: S (3.2286, 3.2286, 3.2286) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'BaSe',
#   'material_id': 'mp-1253',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [616117, 43655, 616124, 53951, 616122, 52696],
#   'e_above_hull': 0.0,
#   'band_gap': 2.2121000000000004,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.72815293100403 4.72815293100403 4.72815293100403
#    angles : 59.99999999999999 59.99999999999999 59.99999999999999
#    volume : 74.74111078246291
#         A : 0.0 3.343309 3.343309
#         B : 3.343309 0.0 3.343309
#         C : 3.343309 3.343309 0.0
#       pbc : True True True
#   PeriodicSite: Ba (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Se (3.3433, 3.3433, 3.3433) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'BaTe',
#   'material_id': 'mp-1000',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [616165, 616163, 29152, 43656],
#   'e_above_hull': 0.0,
#   'band_gap': 1.8555,
#   'structure': Structure Summary
#   Lattice
#       abc : 5.013215958771575 5.013215958771575 5.013215958771575
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 89.09108390126052
#         A : 0.0 3.544879 3.544879
#         B : 3.544879 0.0 3.544879
#         C : 3.544879 3.544879 0.0
#       pbc : True True True
#   PeriodicSite: Ba (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Te (3.5449, 3.5449, 3.5449) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'BrN',
#   'material_id': 'mp-1058019',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [60679, 23986],
#   'e_above_hull': 2.0682408638100003,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.4540483346823625 3.4540483346823625 3.4540483346823625
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 29.13870415311359
#         A : 0.0 2.442381 2.442381
#         B : 2.442381 0.0 2.442381
#         C : 2.442381 2.442381 0.0
#       pbc : True True True
#   PeriodicSite: Br (2.4424, 2.4424, 2.4424) [0.5000, 0.5000, 0.5000]
#   PeriodicSite: N (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]},
#  {'pretty_formula': 'BrO',
#   'material_id': 'mp-1207019',
#   'spacegroup.symbol': 'R-3m',
#   'spacegroup.crystal_system': 'trigonal',
#   'icsd_ids': [22122],
#   'e_above_hull': 0.9085759479166642,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.2966638602552427 3.2966638602552427 3.2966634950708875
#    angles : 68.4318233190208 68.4318233190208 68.43181932600562
#    volume : 29.846062839913976
#         A : 2.726092 -1.853757 0.0
#         B : 2.726092 1.853757 0.0
#         C : 1.465527 0.0 2.953002
#       pbc : True True True
#   PeriodicSite: Br (3.4589, 0.0000, 1.4765) [0.5000, 0.5000, 0.5000]
#   PeriodicSite: O (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]},
#  {'pretty_formula': 'CaN',
#   'material_id': 'mp-1058549',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [27054, 29108, 158967],
#   'e_above_hull': 0.3981652693750002,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.546694879366986 3.546694879366986 3.546694879366986
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 31.546885238045352
#         A : 0.0 2.507892 2.507892
#         B : 2.507892 0.0 2.507892
#         C : 2.507892 2.507892 0.0
#       pbc : True True True
#   PeriodicSite: Ca (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: N (2.5079, 2.5079, 2.5079) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CaO',
#   'material_id': 'mp-2605',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [60199,
#    52783,
#    60704,
#    619461,
#    61550,
#    180198,
#    26959,
#    90486,
#    261847,
#    51409,
#    75786,
#    163628,
#    75785,
#    28905],
#   'e_above_hull': 0.0,
#   'band_gap': 3.6919,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.4218778045654994 3.4218778045654994 3.4218778045654994
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 28.332082162785422
#         A : 0.0 2.419633 2.419633
#         B : 2.419633 0.0 2.419633
#         C : 2.419633 2.419633 0.0
#       pbc : True True True
#   PeriodicSite: Ca (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: O (2.4196, 2.4196, 2.4196) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CaS',
#   'material_id': 'mp-1672',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [619527,
#    619528,
#    619538,
#    52784,
#    619540,
#    60200,
#    30236,
#    619529,
#    186785,
#    619537,
#    619534,
#    603165,
#    619530,
#    53940,
#    28902,
#    41956,
#    619533],
#   'e_above_hull': 0.0,
#   'band_gap': 2.5596,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.04199206688979 4.04199206688979 4.04199206688979
#    angles : 59.99999999999999 59.99999999999999 59.99999999999999
#    volume : 46.69510674901466
#         A : 0.0 2.85812 2.85812
#         B : 2.85812 0.0 2.85812
#         C : 2.85812 2.85812 0.0
#       pbc : True True True
#   PeriodicSite: Ca (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: S (2.8581, 2.8581, 2.8581) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CaSe',
#   'material_id': 'mp-1415',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [619572,
#    186789,
#    619571,
#    187695,
#    52788,
#    619570,
#    60201,
#    53948,
#    41957],
#   'e_above_hull': 0.0,
#   'band_gap': 2.1362,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.2176501192585905 4.2176501192585905 4.2176501192585905
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 53.05137572029519
#         A : 0.0 2.982329 2.982329
#         B : 2.982329 0.0 2.982329
#         C : 2.982329 2.982329 0.0
#       pbc : True True True
#   PeriodicSite: Ca (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Se (2.9823, 2.9823, 2.9823) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CaTe',
#   'material_id': 'mp-1519',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [186787, 619618, 60202, 619616, 41958, 619615],
#   'e_above_hull': 0.0,
#   'band_gap': 1.6040999999999999,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.523523299596455 4.523523299596455 4.523523299596455
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 65.4508810377982
#         A : 0.0 3.198614 3.198614
#         B : 3.198614 0.0 3.198614
#         C : 3.198614 3.198614 0.0
#       pbc : True True True
#   PeriodicSite: Ca (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Te (3.1986, 3.1986, 3.1986) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CdC',
#   'material_id': 'mp-1006887',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [183177],
#   'e_above_hull': 1.9808214699999995,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.433875992428672 3.433875992428672 3.433875992428672
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 28.63115212259255
#         A : 0.0 2.428117 2.428117
#         B : 2.428117 0.0 2.428117
#         C : 2.428117 2.428117 0.0
#       pbc : True True True
#   PeriodicSite: Cd (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: C (2.4281, 2.4281, 2.4281) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CdN',
#   'material_id': 'mp-1008918',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [186890, 183197, 185556],
#   'e_above_hull': 0.8404801988100004,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.367695040350299 3.367695040350299 3.367695040350299
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 27.007430934071937
#         A : 0.0 2.38132 2.38132
#         B : 2.38132 0.0 2.38132
#         C : 2.38132 2.38132 0.0
#       pbc : True True True
#   PeriodicSite: Cd (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: N (2.3813, 2.3813, 2.3813) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CdO',
#   'material_id': 'mp-1132',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [29289,
#    29291,
#    29292,
#    181294,
#    181735,
#    620205,
#    620204,
#    31055,
#    620202,
#    29290,
#    620206,
#    24802,
#    61554,
#    181057],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.382586709162087 3.382586709162087 3.382586709162087
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 27.367291401313242
#         A : 0.0 2.39185 2.39185
#         B : 2.39185 0.0 2.39185
#         C : 2.39185 2.39185 0.0
#       pbc : True True True
#   PeriodicSite: Cd (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: O (2.3918, 2.3918, 2.3918) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CeAs',
#   'material_id': 'mp-2748',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [603004, 610001, 609998, 43882, 52009, 609995],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.225967109218907 4.225967109218907 4.225967109218907
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 53.365838796083324
#         A : 0.0 2.98821 2.98821
#         B : 2.98821 0.0 2.98821
#         C : 2.98821 2.98821 0.0
#       pbc : True True True
#   PeriodicSite: Ce (2.9882, 2.9882, 2.9882) [0.5000, 0.5000, 0.5000]
#   PeriodicSite: As (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]},
#  {'pretty_formula': 'CeAu',
#   'material_id': 'mp-1025468',
#   'spacegroup.symbol': 'Pnma',
#   'spacegroup.crystal_system': 'orthorhombic',
#   'icsd_ids': [611711],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.744928 6.001686 7.409219
#    angles : 90.0 90.0 90.0
#    volume : 210.99653751861743
#         A : 4.744928 0.0 0.0
#         B : 0.0 6.001686 0.0
#         C : 0.0 0.0 7.409219
#       pbc : True True True
#   PeriodicSite: Ce (1.1862, 3.8662, 1.3529) [0.2500, 0.6442, 0.1826]
#   PeriodicSite: Ce (3.5587, 2.1355, 6.0563) [0.7500, 0.3558, 0.8174]
#   PeriodicSite: Ce (3.5587, 0.8653, 2.3517) [0.7500, 0.1442, 0.3174]
#   PeriodicSite: Ce (1.1862, 5.1364, 5.0575) [0.2500, 0.8558, 0.6826]
#   PeriodicSite: Au (1.1862, 0.9190, 0.3055) [0.2500, 0.1531, 0.0412]
#   PeriodicSite: Au (3.5587, 5.0827, 7.1037) [0.7500, 0.8469, 0.9588]
#   PeriodicSite: Au (3.5587, 3.9198, 3.3991) [0.7500, 0.6531, 0.4588]
#   PeriodicSite: Au (1.1862, 2.0819, 4.0101) [0.2500, 0.3469, 0.5412]},
#  {'pretty_formula': 'CeBi',
#   'material_id': 'mp-23285',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [616560, 616547, 616556, 616548, 58765, 187506, 603016],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.611586378125428 4.611586378125428 4.611586378125428
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 69.34833607706096
#         A : 0.0 3.260884 3.260884
#         B : 3.260884 0.0 3.260884
#         C : 3.260884 3.260884 0.0
#       pbc : True True True
#   PeriodicSite: Ce (3.2609, 3.2609, 3.2609) [0.5000, 0.5000, 0.5000]
#   PeriodicSite: Bi (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]},
#  {'pretty_formula': 'CeC',
#   'material_id': 'mp-22672',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [617324, 76769],
#   'e_above_hull': 0.15721525916666845,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.6713959886563585 3.6713959886563585 3.6713959886563585
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 34.99279958158199
#         A : 0.0 2.596069 2.596069
#         B : 2.596069 0.0 2.596069
#         C : 2.596069 2.596069 0.0
#       pbc : True True True
#   PeriodicSite: Ce (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: C (2.5961, 2.5961, 2.5961) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CeN',
#   'material_id': 'mp-2493',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [621549,
#    236534,
#    236504,
#    621559,
#    236537,
#    236536,
#    52881,
#    236530,
#    621558,
#    236500,
#    236503,
#    236498,
#    236483,
#    236482,
#    169213,
#    621548,
#    236490,
#    236535,
#    236494,
#    236493,
#    236491,
#    236485,
#    236495,
#    236508,
#    236496,
#    236492,
#    236501,
#    236506,
#    236502,
#    621551,
#    621550,
#    621547,
#    236505,
#    236532,
#    236487,
#    236486,
#    236510,
#    236509,
#    236484,
#    236531,
#    236497,
#    236511,
#    236533,
#    236499,
#    621553,
#    76480,
#    621546,
#    236489,
#    236488,
#    236507,
#    169198],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.571836768078855 3.571836768078855 3.571836768078855
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 32.22254306393652
#         A : 0.0 2.52567 2.52567
#         B : 2.52567 0.0 2.52567
#         C : 2.52567 2.52567 0.0
#       pbc : True True True
#   PeriodicSite: Ce (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: N (2.5257, 2.5257, 2.5257) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CeO',
#   'material_id': 'mp-10688',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [52886],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.5254929896398886 3.5254929896398886 3.5254929896398886
#    angles : 59.99999999999999 59.99999999999999 59.99999999999999
#    volume : 30.984505434178
#         A : 0.0 2.4929 2.4929
#         B : 2.4929 0.0 2.4929
#         C : 2.4929 2.4929 0.0
#       pbc : True True True
#   PeriodicSite: Ce (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: O (2.4929, 2.4929, 2.4929) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CeP',
#   'material_id': 'mp-2154',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [621750,
#    621755,
#    621760,
#    52006,
#    621758,
#    52889,
#    603003,
#    621749,
#    621746,
#    621754],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.1013593380246505 4.1013593380246505 4.1013593380246505
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 48.78299571053934
#         A : 0.0 2.900099 2.900099
#         B : 2.900099 0.0 2.900099
#         C : 2.900099 2.900099 0.0
#       pbc : True True True
#   PeriodicSite: Ce (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: P (2.9001, 2.9001, 2.9001) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CeS',
#   'material_id': 'mp-1096',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [603041,
#    29397,
#    622013,
#    31706,
#    622035,
#    622033,
#    102279,
#    183945,
#    622039,
#    622029,
#    622009,
#    102280,
#    622016,
#    603087,
#    622010],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.018190852635051 4.018190852635051 4.018190852635051
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 45.875064104557374
#         A : 0.0 2.84129 2.84129
#         B : 2.84129 0.0 2.84129
#         C : 2.84129 2.84129 0.0
#       pbc : True True True
#   PeriodicSite: Ce (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: S (2.8413, 2.8413, 2.8413) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CeSb',
#   'material_id': 'mp-387',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [622097,
#    52012,
#    622094,
#    622102,
#    603005,
#    163722,
#    622093,
#    52902,
#    622087,
#    622092,
#    622084,
#    622080,
#    622095,
#    622098,
#    622101],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.504455458134979 4.504455458134979 4.504455458134979
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 64.62668693880121
#         A : 0.0 3.185131 3.185131
#         B : 3.185131 0.0 3.185131
#         C : 3.185131 3.185131 0.0
#       pbc : True True True
#   PeriodicSite: Ce (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Sb (3.1851, 3.1851, 3.1851) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CeSe',
#   'material_id': 'mp-2563',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [183946, 29398, 603052, 622126, 601537, 52907, 27105],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.1903671112132885 4.1903671112132885 4.1903671112132885
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 52.028489738256184
#         A : 0.0 2.963037 2.963037
#         B : 2.963037 0.0 2.963037
#         C : 2.963037 2.963037 0.0
#       pbc : True True True
#   PeriodicSite: Ce (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Se (2.9630, 2.9630, 2.9630) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CeTe',
#   'material_id': 'mp-1525',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [622266, 622277, 622272, 183947, 52912, 29399, 622275],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.483061235363398 4.483061235363398 4.483061235363398
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 63.71020688037117
#         A : 0.0 3.170003 3.170003
#         B : 3.170003 0.0 3.170003
#         C : 3.170003 3.170003 0.0
#       pbc : True True True
#   PeriodicSite: Ce (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Te (3.1700, 3.1700, 3.1700) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CrH',
#   'material_id': 'mp-24287',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [626118, 191080],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 2.6721805677345234 2.6721805677345234 2.6721805677345234
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 13.4921886994719
#         A : 0.0 1.889517 1.889517
#         B : 1.889517 0.0 1.889517
#         C : 1.889517 1.889517 0.0
#       pbc : True True True
#   PeriodicSite: Cr (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: H (1.8895, 1.8895, 1.8895) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CrO',
#   'material_id': 'mp-19091',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [109296, 61633],
#   'e_above_hull': 1.9506895633333343,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.1473294546341983 3.1473294546341983 3.1473294546341983
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 22.045077028600414
#         A : 0.0 2.225498 2.225498
#         B : 2.225498 0.0 2.225498
#         C : 2.225498 2.225498 0.0
#       pbc : True True True
#   PeriodicSite: Cr (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: O (2.2255, 2.2255, 2.2255) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CrTe',
#   'material_id': 'mp-1009079',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [169767],
#   'e_above_hull': 0.17540467437499885,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.045308397693555 4.045308397693555 4.045308397693555
#    angles : 59.99999999999999 59.99999999999999 59.99999999999999
#    volume : 46.81013679462209
#         A : 0.0 2.860465 2.860465
#         B : 2.860465 0.0 2.860465
#         C : 2.860465 2.860465 0.0
#       pbc : True True True
#   PeriodicSite: Cr (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Te (2.8605, 2.8605, 2.8605) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CsB',
#   'material_id': 'mp-1060982',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [27864],
#   'e_above_hull': 2.1461423718678163,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.893111043559915 4.893111043559915 4.893111043559915
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 82.84002422703081
#         A : 0.0 3.459952 3.459952
#         B : 3.459952 0.0 3.459952
#         C : 3.459952 3.459952 0.0
#       pbc : True True True
#   PeriodicSite: Cs (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: B (3.4600, 3.4600, 3.4600) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CsBr',
#   'material_id': 'mp-571222',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [61516],
#   'e_above_hull': 0.0,
#   'band_gap': 4.4247,
#   'structure': Structure Summary
#   Lattice
#       abc : 5.234073690807381 5.234073690807381 5.234073690807381
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 101.39218929121083
#         A : 0.0 3.701049 3.701049
#         B : 3.701049 0.0 3.701049
#         C : 3.701049 3.701049 0.0
#       pbc : True True True
#   PeriodicSite: Cs (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Br (3.7010, 3.7010, 3.7010) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CsCl',
#   'material_id': 'mp-573697',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [52274, 61515],
#   'e_above_hull': 0.0,
#   'band_gap': 5.0172,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.993597988234335 4.993597988234335 4.993597988234335
#    angles : 59.99999999999999 59.99999999999999 59.99999999999999
#    volume : 88.04926423740011
#         A : 0.0 3.531007 3.531007
#         B : 3.531007 0.0 3.531007
#         C : 3.531007 3.531007 0.0
#       pbc : True True True
#   PeriodicSite: Cs (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Cl (3.5310, 3.5310, 3.5310) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CsF',
#   'material_id': 'mp-1784',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [53832, 44288],
#   'e_above_hull': 0.0,
#   'band_gap': 5.281,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.326086358367109 4.326086358367109 4.326086358367109
#    angles : 59.99999999999999 59.99999999999999 59.99999999999999
#    volume : 57.24934948288885
#         A : 0.0 3.059005 3.059005
#         B : 3.059005 0.0 3.059005
#         C : 3.059005 3.059005 0.0
#       pbc : True True True
#   PeriodicSite: Cs (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: F (3.0590, 3.0590, 3.0590) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CsH',
#   'material_id': 'mp-1057286',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [53236, 69597],
#   'e_above_hull': 0.0,
#   'band_gap': 2.5878,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.557559177402088 4.557559177402088 4.557559177402088
#    angles : 59.99999999999999 59.99999999999999 59.99999999999999
#    volume : 66.9394209884833
#         A : 0.0 3.222681 3.222681
#         B : 3.222681 0.0 3.222681
#         C : 3.222681 3.222681 0.0
#       pbc : True True True
#   PeriodicSite: Cs (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: H (3.2227, 3.2227, 3.2227) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'CsI',
#   'material_id': 'mp-614603',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [61517],
#   'e_above_hull': 0.0,
#   'band_gap': 3.8556,
#   'structure': Structure Summary
#   Lattice
#       abc : 5.557278058352128 5.557278058352128 5.557278058352128
#    angles : 59.99999999999999 59.99999999999999 59.99999999999999
#    volume : 121.35883085961832
#         A : 0.0 3.929589 3.929589
#         B : 3.929589 0.0 3.929589
#         C : 3.929589 3.929589 0.0
#       pbc : True True True
#   PeriodicSite: Cs (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: I (3.9296, 3.9296, 3.9296) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'DyAs',
#   'material_id': 'mp-2627',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [610374, 187520, 43638, 610373, 610371],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.119741285908376 4.119741285908376 4.119741285908376
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 49.441863759610335
#         A : 0.0 2.913097 2.913097
#         B : 2.913097 0.0 2.913097
#         C : 2.913097 2.913097 0.0
#       pbc : True True True
#   PeriodicSite: Dy (2.9131, 2.9131, 2.9131) [0.5000, 0.5000, 0.5000]
#   PeriodicSite: As (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]},
#  {'pretty_formula': 'DyBi',
#   'material_id': 'mp-22907',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [616629, 616632, 58778],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.476562924044295 4.476562924044295 4.476562924044295
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 63.433559578087205
#         A : 0.0 3.165408 3.165408
#         B : 3.165408 0.0 3.165408
#         C : 3.165408 3.165408 0.0
#       pbc : True True True
#   PeriodicSite: Dy (3.1654, 3.1654, 3.1654) [0.5000, 0.5000, 0.5000]
#   PeriodicSite: Bi (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]},
#  {'pretty_formula': 'DyN',
#   'material_id': 'mp-1410',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [106594, 169206, 44775, 169221, 629962, 629961, 76482],
#   'e_above_hull': 0.0,
#   'band_gap': 0.21149999999999958,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.4737949986537777 3.4737949986537777 3.4737949986537777
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 29.641321291784713
#         A : 0.0 2.456344 2.456344
#         B : 2.456344 0.0 2.456344
#         C : 2.456344 2.456344 0.0
#       pbc : True True True
#   PeriodicSite: Dy (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: N (2.4563, 2.4563, 2.4563) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'DyP',
#   'material_id': 'mp-2014',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [187518, 53372, 630056, 630055],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.008315399329 4.008315399329 4.008315399329
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 45.53765513681986
#         A : 0.0 2.834307 2.834307
#         B : 2.834307 0.0 2.834307
#         C : 2.834307 2.834307 0.0
#       pbc : True True True
#   PeriodicSite: Dy (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: P (2.8343, 2.8343, 2.8343) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'DyPt',
#   'material_id': 'mp-1078613',
#   'spacegroup.symbol': 'Pnma',
#   'spacegroup.crystal_system': 'orthorhombic',
#   'icsd_ids': [630127, 630117, 630123],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.556135 5.57155 7.040349
#    angles : 90.0 90.0 90.0
#    volume : 178.7173863452718
#         A : 4.556135 0.0 0.0
#         B : 0.0 5.57155 0.0
#         C : 0.0 0.0 7.040349
#       pbc : True True True
#   PeriodicSite: Dy (1.1390, 2.0172, 4.7956) [0.2500, 0.3621, 0.6812]
#   PeriodicSite: Dy (1.1390, 0.7686, 1.2754) [0.2500, 0.1379, 0.1812]
#   PeriodicSite: Dy (3.4171, 3.5544, 2.2448) [0.7500, 0.6379, 0.3188]
#   PeriodicSite: Dy (3.4171, 4.8030, 5.7649) [0.7500, 0.8621, 0.8188]
#   PeriodicSite: Pt (1.1390, 4.7225, 3.8384) [0.2500, 0.8476, 0.5452]
#   PeriodicSite: Pt (1.1390, 3.6349, 0.3182) [0.2500, 0.6524, 0.0452]
#   PeriodicSite: Pt (3.4171, 0.8491, 3.2020) [0.7500, 0.1524, 0.4548]
#   PeriodicSite: Pt (3.4171, 1.9367, 6.7222) [0.7500, 0.3476, 0.9548]},
#  {'pretty_formula': 'DyS',
#   'material_id': 'mp-2470',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [630204, 53377, 57239, 630186],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.904244837487526 3.904244837487526 3.904244837487526
#    angles : 59.99999999999999 59.99999999999999 59.99999999999999
#    volume : 42.081977158617725
#         A : 0.0 2.760718 2.760718
#         B : 2.760718 0.0 2.760718
#         C : 2.760718 2.760718 0.0
#       pbc : True True True
#   PeriodicSite: Dy (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: S (2.7607, 2.7607, 2.7607) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'DySb',
#   'material_id': 'mp-1007',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [103368,
#    630247,
#    103367,
#    630227,
#    630232,
#    630240,
#    630231,
#    630241,
#    43639,
#    630238],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.387041791332515 4.387041791332515 4.387041791332515
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 59.70357221245925
#         A : 0.0 3.102107 3.102107
#         B : 3.102107 0.0 3.102107
#         C : 3.102107 3.102107 0.0
#       pbc : True True True
#   PeriodicSite: Dy (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Sb (3.1021, 3.1021, 3.1021) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'DySe',
#   'material_id': 'mp-814',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [630250, 53380],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.0763235153299595 4.0763235153299595 4.0763235153299595
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 47.89508352321047
#         A : 0.0 2.882396 2.882396
#         B : 2.882396 0.0 2.882396
#         C : 2.882396 2.882396 0.0
#       pbc : True True True
#   PeriodicSite: Dy (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Se (2.8824, 2.8824, 2.8824) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'DyTe',
#   'material_id': 'mp-2159',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [43640, 53385, 630335, 630344],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.354731254072977 4.354731254072977 4.354731254072977
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 58.39411450283755
#         A : 0.0 3.07926 3.07926
#         B : 3.07926 0.0 3.07926
#         C : 3.07926 3.07926 0.0
#       pbc : True True True
#   PeriodicSite: Dy (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Te (3.0793, 3.0793, 3.0793) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'ErAs',
#   'material_id': 'mp-1688',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [167762, 602416, 43644, 610387],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.083380441006201 4.083380441006201 4.083380441006201
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 48.144262112027725
#         A : 0.0 2.887386 2.887386
#         B : 2.887386 0.0 2.887386
#         C : 2.887386 2.887386 0.0
#       pbc : True True True
#   PeriodicSite: Er (2.8874, 2.8874, 2.8874) [0.5000, 0.5000, 0.5000]
#   PeriodicSite: As (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]},
#  {'pretty_formula': 'ErBi',
#   'material_id': 'mp-23245',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [656440, 58781, 616641],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.448117432450721 4.448117432450721 4.448117432450721
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 62.23199664919814
#         A : 0.0 3.145294 3.145294
#         B : 3.145294 0.0 3.145294
#         C : 3.145294 3.145294 0.0
#       pbc : True True True
#   PeriodicSite: Er (3.1453, 3.1453, 3.1453) [0.5000, 0.5000, 0.5000]
#   PeriodicSite: Bi (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]},
#  {'pretty_formula': 'ErN',
#   'material_id': 'mp-19830',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [236518,
#    44777,
#    236512,
#    236548,
#    630800,
#    630798,
#    53399,
#    236551,
#    169223,
#    236547,
#    236514,
#    106611,
#    167758,
#    630795,
#    236517,
#    76483,
#    236550,
#    236516,
#    236546,
#    236549,
#    236552,
#    236513,
#    630799,
#    236519,
#    630801,
#    236515,
#    169208],
#   'e_above_hull': 0.0,
#   'band_gap': 0.27159999999999984,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.4281413564332497 3.4281413564332497 3.4281413564332497
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 28.48794789257962
#         A : 0.0 2.424062 2.424062
#         B : 2.424062 0.0 2.424062
#         C : 2.424062 2.424062 0.0
#       pbc : True True True
#   PeriodicSite: Er (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: N (2.4241, 2.4241, 2.4241) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'ErP',
#   'material_id': 'mp-1144',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [167760, 53407, 630908],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.9693057324245 3.9693057324245 3.9693057324245
#    angles : 59.99999999999999 59.99999999999999 59.99999999999999
#    volume : 44.2210098663893
#         A : 0.0 2.806723 2.806723
#         B : 2.806723 0.0 2.806723
#         C : 2.806723 2.806723 0.0
#       pbc : True True True
#   PeriodicSite: Er (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: P (2.8067, 2.8067, 2.8067) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'ErPt',
#   'material_id': 'mp-1025444',
#   'spacegroup.symbol': 'Pnma',
#   'spacegroup.crystal_system': 'orthorhombic',
#   'icsd_ids': [630978, 630968],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.449081 5.606139 6.983468
#    angles : 90.0 90.0 90.0
#    volume : 174.18282166109844
#         A : 4.449081 0.0 0.0
#         B : 0.0 5.606139 0.0
#         C : 0.0 0.0 6.983468
#       pbc : True True True
#   PeriodicSite: Er (1.1123, 3.5861, 1.2666) [0.2500, 0.6397, 0.1814]
#   PeriodicSite: Er (3.3368, 2.0201, 5.7169) [0.7500, 0.3603, 0.8186]
#   PeriodicSite: Er (3.3368, 0.7830, 2.2251) [0.7500, 0.1397, 0.3186]
#   PeriodicSite: Er (1.1123, 4.8231, 4.7583) [0.2500, 0.8603, 0.6814]
#   PeriodicSite: Pt (1.1123, 0.8798, 0.3117) [0.2500, 0.1569, 0.0446]
#   PeriodicSite: Pt (3.3368, 4.7264, 6.6718) [0.7500, 0.8431, 0.9554]
#   PeriodicSite: Pt (3.3368, 3.6828, 3.1801) [0.7500, 0.6569, 0.4554]
#   PeriodicSite: Pt (1.1123, 1.9233, 3.8034) [0.2500, 0.3431, 0.5446]},
#  {'pretty_formula': 'ErS',
#   'material_id': 'mp-1623',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [631063, 53414, 631056, 106619, 631067],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.863857726573275 3.863857726573275 3.863857726573275
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 40.789500026683385
#         A : 0.0 2.73216 2.73216
#         B : 2.73216 0.0 2.73216
#         C : 2.73216 2.73216 0.0
#       pbc : True True True
#   PeriodicSite: Er (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: S (2.7322, 2.7322, 2.7322) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'ErSb',
#   'material_id': 'mp-2191',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [631099, 53417, 631092, 43645, 631097, 631102, 631100, 631095],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.354982984087079 4.354982984087079 4.354982984087079
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 58.40424169564211
#         A : 0.0 3.079438 3.079438
#         B : 3.079438 0.0 3.079438
#         C : 3.079438 3.079438 0.0
#       pbc : True True True
#   PeriodicSite: Er (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Sb (3.0794, 3.0794, 3.0794) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'ErSe',
#   'material_id': 'mp-2491',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [631103, 53418, 631118, 631110, 600371],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.0367623051361345 4.0367623051361345 4.0367623051361345
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 46.51409071777272
#         A : 0.0 2.854422 2.854422
#         B : 2.854422 0.0 2.854422
#         C : 2.854422 2.854422 0.0
#       pbc : True True True
#   PeriodicSite: Er (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Se (2.8544, 2.8544, 2.8544) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'ErTe',
#   'material_id': 'mp-1280',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [43646, 631186, 631173],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.319677142502435 4.319677142502435 4.319677142502435
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 56.99527681542986
#         A : 0.0 3.054473 3.054473
#         B : 3.054473 0.0 3.054473
#         C : 3.054473 3.054473 0.0
#       pbc : True True True
#   PeriodicSite: Er (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Te (3.0545, 3.0545, 3.0545) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'EuN',
#   'material_id': 'mp-20340',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [1565, 164616, 169218, 169203, 631405, 44772],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.5913358185455175 3.591335422323289 3.591335
#    angles : 59.999994679028816 59.9999983286258 60.000000554117825
#    volume : 32.753135750070925
#         A : 3.110188 0.0 1.795668
#         B : 1.036729 2.932313 1.795668
#         C : 0.0 0.0 3.591335
#       pbc : True True True
#   PeriodicSite: Eu (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: N (2.0735, 1.4662, 3.5913) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'EuO',
#   'material_id': 'mp-21394',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [53437, 631466, 631458, 631469, 631456],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.5943185210799005 3.5943185210799005 3.5943185210799005
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 32.834823372547866
#         A : 0.0 2.541567 2.541567
#         B : 2.541567 0.0 2.541567
#         C : 2.541567 2.541567 0.0
#       pbc : True True True
#   PeriodicSite: Eu (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: O (2.5416, 2.5416, 2.5416) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'EuP',
#   'material_id': 'mp-20300',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [631476, 53438],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.157678978932596 4.157678978932596 4.157678978932596
#    angles : 59.99999999999999 59.99999999999999 59.99999999999999
#    volume : 50.82037476138664
#         A : 0.0 2.939923 2.939923
#         B : 2.939923 0.0 2.939923
#         C : 2.939923 2.939923 0.0
#       pbc : True True True
#   PeriodicSite: Eu (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: P (2.9399, 2.9399, 2.9399) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'EuS',
#   'material_id': 'mp-20587',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [53439,
#    631614,
#    30206,
#    657615,
#    631613,
#    631600,
#    631591,
#    631606,
#    631588,
#    631612,
#    631595,
#    631605,
#    183948,
#    631599,
#    631589,
#    631602,
#    631603,
#    631609],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.132930241591068 4.132930241591068 4.132930241591068
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 49.91823569032661
#         A : 0.0 2.922423 2.922423
#         B : 2.922423 0.0 2.922423
#         C : 2.922423 2.922423 0.0
#       pbc : True True True
#   PeriodicSite: Eu (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: S (2.9224, 2.9224, 2.9224) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'EuSe',
#   'material_id': 'mp-21009',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [657616, 183949, 631658, 631657, 631659, 631663, 631661, 27109],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.346623567719892 4.346623567719892 4.346623567719892
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 58.06856496135802
#         A : 0.0 3.073527 3.073527
#         B : 3.073527 0.0 3.073527
#         C : 3.073527 3.073527 0.0
#       pbc : True True True
#   PeriodicSite: Eu (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Se (3.0735, 3.0735, 3.0735) [0.5000, 0.5000, 0.5000]},
#  {'pretty_formula': 'EuTe',
#   'material_id': 'mp-542583',
#   'spacegroup.symbol': 'Fm-3m',
#   'spacegroup.crystal_system': 'cubic',
# ...
#   'spacegroup.symbol': 'F-43m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [184576],
#   'e_above_hull': 0.2337322204999981,
#   'band_gap': 0.12659999999999982,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.327493500861671 4.327493500861671 4.327493500861671
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 57.305232000000004
#         A : 0.0 3.06 3.06
#         B : 3.06 0.0 3.06
#         C : 3.06 3.06 0.0
#       pbc : True True True
#   PeriodicSite: Tl (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: P (1.5300, 1.5300, 1.5300) [0.2500, 0.2500, 0.2500]},
#  {'pretty_formula': 'TlSb',
#   'material_id': 'mp-1002219',
#   'spacegroup.symbol': 'F-43m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [184577],
#   'e_above_hull': 0.15283173369047587,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.802669257819031 4.802669257819031 4.802669257819031
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 78.33088627199999
#         A : 0.0 3.396 3.396
#         B : 3.396 0.0 3.396
#         C : 3.396 3.396 0.0
#       pbc : True True True
#   PeriodicSite: Tl (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Sb (1.6980, 1.6980, 1.6980) [0.2500, 0.2500, 0.2500]},
#  {'pretty_formula': 'ZnN',
#   'material_id': 'mp-999485',
#   'spacegroup.symbol': 'F-43m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [236798, 236797],
#   'e_above_hull': 0.46050283127000036,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.247445875355277 3.247445875355277 3.247445875355277
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 24.21646608015074
#         A : 0.0 2.296291 2.296291
#         B : 2.296291 0.0 2.296291
#         C : 2.296291 2.296291 0.0
#       pbc : True True True
#   PeriodicSite: Zn (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: N (1.1481, 1.1481, 1.1481) [0.2500, 0.2500, 0.2500]},
#  {'pretty_formula': 'ZnSe',
#   'material_id': 'mp-1190',
#   'spacegroup.symbol': 'F-43m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [652220,
#    53952,
#    652214,
#    652210,
#    181761,
#    652228,
#    41527,
#    652224,
#    181672,
#    652221,
#    167830,
#    652211,
#    162755,
#    188389,
#    652226,
#    77091,
#    652209,
#    652212,
#    77092,
#    652216,
#    652215,
#    652222,
#    52454,
#    652225,
#    652227,
#    41983,
#    652223,
#    185134],
#   'e_above_hull': 0.0,
#   'band_gap': 1.6143,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.06044755387876 4.06044755387876 4.06044755387876
#    angles : 60.00000000000001 60.00000000000001 60.00000000000001
#    volume : 47.33765261366124
#         A : 0.0 2.87117 2.87117
#         B : 2.87117 0.0 2.87117
#         C : 2.87117 2.87117 0.0
#       pbc : True True True
#   PeriodicSite: Zn (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Se (1.4356, 1.4356, 1.4356) [0.2500, 0.2500, 0.2500]},
#  {'pretty_formula': 'ZnTe',
#   'material_id': 'mp-2176',
#   'spacegroup.symbol': 'F-43m',
#   'spacegroup.crystal_system': 'cubic',
#   'icsd_ids': [653196,
#    77072,
#    41984,
#    184482,
#    184484,
#    52513,
#    184483,
#    653194,
#    77073,
#    653193,
#    77074,
#    653205,
#    31843,
#    185141,
#    248451,
#    162756,
#    653199,
#    104196,
#    653195,
#    77075,
#    184481,
#    43713,
#    67792,
#    603959,
#    187453,
#    653198,
#    184485],
#   'e_above_hull': 0.0,
#   'band_gap': 1.0782000000000003,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.3733324050588696 4.3733324050588696 4.3733324050588696
#    angles : 59.99999999999999 59.99999999999999 59.99999999999999
#    volume : 59.14560337032898
#         A : 0.0 3.092413 3.092413
#         B : 3.092413 0.0 3.092413
#         C : 3.092413 3.092413 0.0
#       pbc : True True True
#   PeriodicSite: Zn (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
#   PeriodicSite: Te (4.6386, 4.6386, 4.6386) [0.7500, 0.7500, 0.7500]},
#  {'pretty_formula': 'AlN',
#   'material_id': 'mp-661',
#   'spacegroup.symbol': 'P6_3mc',
#   'spacegroup.crystal_system': 'hexagonal',
#   'icsd_ids': [608626,
#    608627,
#    602460,
#    190420,
#    44107,
#    54697,
#    161881,
#    82790,
#    602459,
#    191772,
#    183638,
#    185441,
#    42001,
#    34475,
#    44106,
#    608624,
#    41480,
#    163953,
#    31169,
#    181362,
#    34236,
#    41482,
#    67767,
#    41542],
#   'e_above_hull': 0.0,
#   'band_gap': 4.0536,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.128588271953502 3.128588271953502 5.016955
#    angles : 90.0 90.0 120.00000575093206
#    volume : 42.52728307818043
#         A : 1.564294 -2.709437 0.0
#         B : 1.564294 2.709437 0.0
#         C : 0.0 0.0 5.016955
#       pbc : True True True
#   PeriodicSite: Al (1.5643, -0.9031, 2.5049) [0.6667, 0.3333, 0.4993]
#   PeriodicSite: Al (1.5643, 0.9031, 5.0134) [0.3333, 0.6667, 0.9993]
#   PeriodicSite: N (1.5643, -0.9031, 4.4185) [0.6667, 0.3333, 0.8807]
#   PeriodicSite: N (1.5643, 0.9031, 1.9100) [0.3333, 0.6667, 0.3807]},
#  {'pretty_formula': 'BeO',
#   'material_id': 'mp-2542',
#   'spacegroup.symbol': 'P6_3mc',
#   'spacegroup.crystal_system': 'hexagonal',
#   'icsd_ids': [601160,
#    20703,
#    62726,
#    62729,
#    62733,
#    61181,
#    77373,
#    62737,
#    62736,
#    62727,
#    15620,
#    34237,
#    62735,
#    616377,
#    29271,
#    163468,
#    34238,
#    290880,
#    41485,
#    62731,
#    31072,
#    62728,
#    56144,
#    31825,
#    62730,
#    62738,
#    62734,
#    163819,
#    62732,
#    162675,
#    62534,
#    391224],
#   'e_above_hull': 0.0,
#   'band_gap': 7.463099999999999,
#   'structure': Structure Summary
#   Lattice
#       abc : 2.709710262502063 2.709710262502063 4.402034
#    angles : 90.0 90.0 120.000006409171
#    volume : 27.991727944331426
#         A : 1.354855 -2.346678 0.0
#         B : 1.354855 2.346678 0.0
#         C : 0.0 0.0 4.402034
#       pbc : True True True
#   PeriodicSite: Be (1.3549, 0.7822, 2.2012) [0.3333, 0.6667, 0.5000]
#   PeriodicSite: Be (1.3549, -0.7822, 0.0002) [0.6667, 0.3333, 0.0000]
#   PeriodicSite: O (1.3549, 0.7822, 0.5382) [0.3333, 0.6667, 0.1223]
#   PeriodicSite: O (1.3549, -0.7822, 2.7392) [0.6667, 0.3333, 0.6223]},
#  {'pretty_formula': 'CdS',
#   'material_id': 'mp-672',
#   'spacegroup.symbol': 'P6_3mc',
#   'spacegroup.crystal_system': 'hexagonal',
#   'icsd_ids': [154187,
#    154186,
#    41490,
#    43599,
#    246892,
#    620313,
#    620325,
#    67776,
#    620327,
#    154188,
#    604522,
#    602958,
#    620303,
#    600365,
#    620308,
#    659045,
#    31074,
#    620319,
#    620323,
#    620306,
#    60629,
#    620310,
#    192568],
#   'e_above_hull': 0.0,
#   'band_gap': 1.1162,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.206535101123013 4.206535101123013 6.842929
#    angles : 90.0 90.0 119.99998586265815
#    volume : 104.86287534018373
#         A : 2.103268 -3.642966 0.0
#         B : 2.103268 3.642966 0.0
#         C : 0.0 0.0 6.842929
#       pbc : True True True
#   PeriodicSite: Cd (2.1033, -1.2143, 3.4225) [0.6667, 0.3333, 0.5002]
#   PeriodicSite: Cd (2.1033, 1.2143, 0.0011) [0.3333, 0.6667, 0.0002]
#   PeriodicSite: S (2.1033, -1.2143, 6.0002) [0.6667, 0.3333, 0.8768]
#   PeriodicSite: S (2.1033, 1.2143, 2.5787) [0.3333, 0.6667, 0.3768]},
#  {'pretty_formula': 'CuH',
#   'material_id': 'mp-24093',
#   'spacegroup.symbol': 'P6_3mc',
#   'spacegroup.crystal_system': 'hexagonal',
#   'icsd_ids': [44859],
#   'e_above_hull': 0.06166470819000036,
#   'band_gap': 0.7310000000000008,
#   'structure': Structure Summary
#   Lattice
#       abc : 2.8486072262725166 2.8486072262725166 4.57125
#    angles : 90.0 90.0 119.99998203002504
#    volume : 32.12408948466312
#         A : 1.424304 -2.466966 0.0
#         B : 1.424304 2.466966 0.0
#         C : 0.0 0.0 4.57125
#       pbc : True True True
#   PeriodicSite: Cu (1.4243, -0.8223, 2.2754) [0.6667, 0.3333, 0.4978]
#   PeriodicSite: Cu (1.4243, 0.8223, 4.5610) [0.3333, 0.6667, 0.9978]
#   PeriodicSite: H (1.4243, -0.8223, 4.0101) [0.6667, 0.3333, 0.8772]
#   PeriodicSite: H (1.4243, 0.8223, 1.7245) [0.3333, 0.6667, 0.3772]},
#  {'pretty_formula': 'GaN',
#   'material_id': 'mp-804',
#   'spacegroup.symbol': 'P6_3mc',
#   'spacegroup.crystal_system': 'hexagonal',
#   'icsd_ids': [153890,
#    54698,
#    153891,
#    191773,
#    153889,
#    67769,
#    157512,
#    25676,
#    190424,
#    87830,
#    634715,
#    181358,
#    41481,
#    157398,
#    42000,
#    153887,
#    41543,
#    184926,
#    153888,
#    34476,
#    41483,
#    156259],
#   'e_above_hull': 0.0,
#   'band_gap': 1.7375999999999996,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.2162901334217344 3.2162901334217344 5.239962
#    angles : 90.0 90.0 120.00000274450079
#    volume : 46.9428220153705
#         A : 1.608145 -2.785389 0.0
#         B : 1.608145 2.785389 0.0
#         C : 0.0 0.0 5.239962
#       pbc : True True True
#   PeriodicSite: Ga (1.6081, -0.9285, 2.6154) [0.6667, 0.3333, 0.4991]
#   PeriodicSite: Ga (1.6081, 0.9285, 5.2354) [0.3333, 0.6667, 0.9991]
#   PeriodicSite: N (1.6081, -0.9285, 4.5896) [0.6667, 0.3333, 0.8759]
#   PeriodicSite: N (1.6081, 0.9285, 1.9696) [0.3333, 0.6667, 0.3759]},
#  {'pretty_formula': 'InN',
#   'material_id': 'mp-22205',
#   'spacegroup.symbol': 'P6_3mc',
#   'spacegroup.crystal_system': 'hexagonal',
#   'icsd_ids': [184927,
#    162684,
#    157515,
#    67768,
#    181366,
#    41999,
#    640026,
#    191774,
#    41544,
#    190428,
#    25677,
#    109463],
#   'e_above_hull': 0.0,
#   'band_gap': 0.47770000000000046,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.583882124564088 3.583882124564088 5.790932
#    angles : 90.0 90.0 120.00000229948793
#    volume : 64.4149273151787
#         A : 1.791941 -3.103733 0.0
#         B : 1.791941 3.103733 0.0
#         C : 0.0 0.0 5.790932
#       pbc : True True True
#   PeriodicSite: In (1.7919, -1.0346, 2.8975) [0.6667, 0.3333, 0.5004]
#   PeriodicSite: In (1.7919, 1.0346, 0.0021) [0.3333, 0.6667, 0.0004]
#   PeriodicSite: N (1.7919, -1.0346, 5.0939) [0.6667, 0.3333, 0.8796]
#   PeriodicSite: N (1.7919, 1.0346, 2.1985) [0.3333, 0.6667, 0.3796]},
#  {'pretty_formula': 'LaN',
#   'material_id': 'mp-567290',
#   'spacegroup.symbol': 'P6_3mc',
#   'spacegroup.crystal_system': 'hexagonal',
#   'icsd_ids': [162195],
#   'e_above_hull': 0.0,
#   'band_gap': 1.1489000000000003,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.1328646803615525 4.1328646803615525 5.960067
#    angles : 90.0 90.0 120.00001089132122
#    volume : 88.16254069390989
#         A : 2.066432 -3.579166 0.0
#         B : 2.066432 3.579166 0.0
#         C : 0.0 0.0 5.960067
#       pbc : True True True
#   PeriodicSite: La (2.0664, 1.1931, 5.9526) [0.3333, 0.6667, 0.9987]
#   PeriodicSite: La (2.0664, -1.1931, 2.9725) [0.6667, 0.3333, 0.4987]
#   PeriodicSite: N (2.0664, 1.1931, 2.4511) [0.3333, 0.6667, 0.4113]
#   PeriodicSite: N (2.0664, -1.1931, 5.4312) [0.6667, 0.3333, 0.9113]},
#  {'pretty_formula': 'LiI',
#   'material_id': 'mp-570935',
#   'spacegroup.symbol': 'P6_3mc',
#   'spacegroup.crystal_system': 'hexagonal',
#   'icsd_ids': [414242],
#   'e_above_hull': 0.0,
#   'band_gap': 4.381,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.5660730650739705 4.5660730650739705 7.423565
#    angles : 90.0 90.0 119.99998645352156
#    volume : 134.03830271037458
#         A : 2.283037 -3.954335 0.0
#         B : 2.283037 3.954335 0.0
#         C : 0.0 0.0 7.423565
#       pbc : True True True
#   PeriodicSite: Li (2.2830, 1.3181, 7.4202) [0.3333, 0.6667, 0.9995]
#   PeriodicSite: Li (2.2830, -1.3181, 3.7084) [0.6667, 0.3333, 0.4995]
#   PeriodicSite: I (2.2830, 1.3181, 2.7872) [0.3333, 0.6667, 0.3755]
#   PeriodicSite: I (2.2830, -1.3181, 6.4990) [0.6667, 0.3333, 0.8755]},
#  {'pretty_formula': 'MgTe',
#   'material_id': 'mp-1039',
#   'spacegroup.symbol': 'P6_3mc',
#   'spacegroup.crystal_system': 'hexagonal',
#   'icsd_ids': [52363, 642882, 168348, 642883],
#   'e_above_hull': 0.0,
#   'band_gap': 2.3619999999999997,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.61088068086781 4.61088068086781 7.509375
#    angles : 90.0 90.0 120.00000976946787
#    volume : 138.26178168678
#         A : 2.30544 -3.99314 0.0
#         B : 2.30544 3.99314 0.0
#         C : 0.0 0.0 7.509375
#       pbc : True True True
#   PeriodicSite: Mg (2.3054, 1.3310, 7.4860) [0.3333, 0.6667, 0.9969]
#   PeriodicSite: Mg (2.3054, -1.3310, 3.7313) [0.6667, 0.3333, 0.4969]
#   PeriodicSite: Te (2.3054, 1.3310, 2.8018) [0.3333, 0.6667, 0.3731]
#   PeriodicSite: Te (2.3054, -1.3310, 6.5565) [0.6667, 0.3333, 0.8731]},
#  {'pretty_formula': 'MnSe',
#   'material_id': 'mp-999540',
#   'spacegroup.symbol': 'P6_3mc',
#   'spacegroup.crystal_system': 'hexagonal',
#   'icsd_ids': [643594],
#   'e_above_hull': 0.0,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.204585750241395 4.204585750241395 6.839229
#    angles : 90.0 90.0 119.99999607002988
#    volume : 104.7090508049385
#         A : 2.102293 -3.641278 0.0
#         B : 2.102293 3.641278 0.0
#         C : 0.0 0.0 6.839229
#       pbc : True True True
#   PeriodicSite: Mn (2.1023, -1.2138, 3.4188) [0.6667, 0.3333, 0.4999]
#   PeriodicSite: Mn (2.1023, 1.2138, 6.8384) [0.3333, 0.6667, 0.9999]
#   PeriodicSite: Se (2.1023, -1.2138, 5.9920) [0.6667, 0.3333, 0.8761]
#   PeriodicSite: Se (2.1023, 1.2138, 2.5723) [0.3333, 0.6667, 0.3761]},
#  {'pretty_formula': 'TlN',
#   'material_id': 'mp-1017982',
#   'spacegroup.symbol': 'P6_3mc',
#   'spacegroup.crystal_system': 'hexagonal',
#   'icsd_ids': [644794, 186556],
#   'e_above_hull': 0.7214423488100001,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.7294473850413814 3.7294473850413814 6.085808
#    angles : 90.0 90.0 119.99998909078703
#    volume : 73.30572532325563
#         A : 1.864724 -3.229796 0.0
#         B : 1.864724 3.229796 0.0
#         C : 0.0 0.0 6.085808
#       pbc : True True True
#   PeriodicSite: Tl (1.8647, -1.0766, 3.0409) [0.6667, 0.3333, 0.4997]
#   PeriodicSite: Tl (1.8647, 1.0766, 6.0838) [0.3333, 0.6667, 0.9997]
#   PeriodicSite: N (1.8647, -1.0766, 5.3271) [0.6667, 0.3333, 0.8753]
#   PeriodicSite: N (1.8647, 1.0766, 2.2841) [0.3333, 0.6667, 0.3753]},
#  {'pretty_formula': 'ZnBi',
#   'material_id': 'mp-1064405',
#   'spacegroup.symbol': 'P6_3mc',
#   'spacegroup.crystal_system': 'hexagonal',
#   'icsd_ids': [100115],
#   'e_above_hull': 0.24291856249999988,
#   'band_gap': 0.0,
#   'structure': Structure Summary
#   Lattice
#       abc : 4.7065442874951255 4.7065442874951255 6.355445
#    angles : 90.0 90.0 120.00000404129294
#    volume : 121.92166306639815
#         A : 2.353272 -4.075987 0.0
#         B : 2.353272 4.075987 0.0
#         C : 0.0 0.0 6.355445
#       pbc : True True True
#   PeriodicSite: Zn (2.3533, 1.3587, 3.4154) [0.3333, 0.6667, 0.5374]
#   PeriodicSite: Zn (2.3533, -1.3587, 0.2377) [0.6667, 0.3333, 0.0374]
#   PeriodicSite: Bi (2.3533, 1.3587, 0.5122) [0.3333, 0.6667, 0.0806]
#   PeriodicSite: Bi (2.3533, -1.3587, 3.6899) [0.6667, 0.3333, 0.5806]},
#  {'pretty_formula': 'ZnO',
#   'material_id': 'mp-2133',
#   'spacegroup.symbol': 'P6_3mc',
#   'spacegroup.crystal_system': 'hexagonal',
#   'icsd_ids': [193696,
#    195802,
#    31060,
#    166353,
#    166356,
#    154488,
#    165014,
#    165011,
#    57478,
#    181473,
#    94004,
#    94002,
#    185828,
#    34477,
#    656331,
#    65119,
#    164209,
#    182355,
#    184793,
#    154487,
#    162843,
#    155780,
#    647681,
#    165009,
#    189104,
#    184674,
#    182356,
#    161836,
#    65120,
#    165010,
#    164690,
#    185829,
#    65121,
#    169463,
#    165013,
#    165012,
#    67848,
#    67454,
#    67849,
#    647667,
#    236619,
#    165002,
#    166354,
#    166355,
#    26170,
#    184079,
#    154489,
#    157724,
#    166243,
#    154486,
#    82029,
#    181731,
#    163380,
#    191642,
#    82028,
#    154490,
#    57450,
#    76641,
#    157132,
#    29272,
#    236754,
#    185827,
#    41488,
#    52362,
#    167690,
#    31052,
#    65122,
#    180052,
#    157133],
#   'e_above_hull': 0.0,
#   'band_gap': 0.7316,
#   'structure': Structure Summary
#   Lattice
#       abc : 3.28910296333362 3.28910296333362 5.306821
#    angles : 90.0 90.0 120.00001937720917
#    volume : 49.71871824836267
#         A : 1.644551 -2.848447 0.0
#         B : 1.644551 2.848447 0.0
#         C : 0.0 0.0 5.306821
#       pbc : True True True
#   PeriodicSite: Zn (1.6446, -0.9495, 2.6563) [0.6667, 0.3333, 0.5005]
#   PeriodicSite: Zn (1.6446, 0.9495, 0.0029) [0.3333, 0.6667, 0.0005]
#   PeriodicSite: O (1.6446, -0.9495, 4.6687) [0.6667, 0.3333, 0.8798]
#   PeriodicSite: O (1.6446, 0.9495, 2.0153) [0.3333, 0.6667, 0.3798]}]

# %%
fitted_df = pd.DataFrame(fitted_data)
fitted_df
# Out:
#     pretty_formula material_id spacegroup.symbol spacegroup.crystal_system  \
# 0             AgBr    mp-23231             Fm-3m                     cubic
# 1              AgC  mp-1008653             Fm-3m                     cubic
# 2             AgCl    mp-22922             Fm-3m                     cubic
# 3              AgF     mp-7592             Fm-3m                     cubic
# 4              AgN  mp-1056955             Fm-3m                     cubic
# ..             ...         ...               ...                       ...
# 685           MgTe     mp-1039            P6_3mc                 hexagonal
# 686           MnSe   mp-999540            P6_3mc                 hexagonal
# 687            TlN  mp-1017982            P6_3mc                 hexagonal
# 688           ZnBi  mp-1064405            P6_3mc                 hexagonal
# 689            ZnO     mp-2133            P6_3mc                 hexagonal
#
#                                               icsd_ids  e_above_hull  \
# 0    [56548, 56547, 65061, 53850, 56546, 52246, 650...      0.037294
# 1                                             [183175]      2.235510
# 2                 [56540, 56539, 157535, 56538, 64734]      0.000000
# 3                                              [18008]      0.000000
# 4                             [167858, 185555, 183195]      1.408179
# ..                                                 ...           ...
# 685                    [52363, 642882, 168348, 642883]      0.000000
# 686                                           [643594]      0.000000
# 687                                   [644794, 186556]      0.721442
# 688                                           [100115]      0.242919
# 689  [193696, 195802, 31060, 166353, 166356, 154488...      0.000000
#
#      band_gap                                          structure
# 0      0.7946   [[0. 0. 0.] Ag, [2.925814 2.925814 2.925814] Br]
# 1      0.0000    [[0. 0. 0.] Ag, [2.333879 2.333879 2.333879] C]
# 2      1.2003   [[0. 0. 0.] Ag, [2.811198 2.811198 2.811198] Cl]
# 3      0.0000    [[0. 0. 0.] Ag, [2.514648 2.514648 2.514648] F]
# 4      0.0000       [[0. 0. 0.] Ag, [2.30808 2.30808 2.30808] N]
# ..        ...                                                ...
# 685    2.3620  [[2.30544    1.33104933 7.48602835] Mg, [ 2.30...
# 686    0.0000  [[ 2.102293   -1.21376176  3.41882115] Mn, [2....
# 687    0.0000  [[ 1.864724   -1.07660082  3.0409322 ] Tl, [1....
# 688    0.0000  [[2.353272   1.35866505 3.41544156] Zn, [ 2.35...
# 689    0.7316  [[ 1.644551   -0.94948423  2.65631864] Zn, [1....
#
# [690 rows x 8 columns]

# %%
fitted_df.to_csv('data_filtered_structs.csv',index=False)

# %%
#This creates the database object
DB=database.StructureDB("Binary_structures_filtered.db")

#These create tables within the database
DB.add_table("Experimental")

# %%
structs=[]
for i in fitted_data:
    structs.append(database.parse_mprest(i))
# Out:
# Couldn't decorate mp-8023 with oxidation states.
# Couldn't decorate mp-1008610 with oxidation states.
# Couldn't decorate mp-1057758 with oxidation states.
# Couldn't decorate mp-1058549 with oxidation states.
# Couldn't decorate mp-1008918 with oxidation states.
# Couldn't decorate mp-1025468 with oxidation states.
# Couldn't decorate mp-24287 with oxidation states.
# Couldn't decorate mp-22907 with oxidation states.
# Couldn't decorate mp-1078613 with oxidation states.
# Couldn't decorate mp-1025444 with oxidation states.
# Couldn't decorate mp-1623 with oxidation states.
# Couldn't decorate mp-2491 with oxidation states.
# Couldn't decorate mp-1280 with oxidation states.
# Couldn't decorate mp-11428 with oxidation states.
# Couldn't decorate mp-24289 with oxidation states.
# Couldn't decorate mp-1007755 with oxidation states.
# Couldn't decorate mp-22866 with oxidation states.
# Couldn't decorate mp-1087502 with oxidation states.
# Couldn't decorate mp-1079180 with oxidation states.
# Couldn't decorate mp-1025438 with oxidation states.
# Couldn't decorate mp-656 with oxidation states.
# Couldn't decorate mp-414 with oxidation states.
# Couldn't decorate mp-1254 with oxidation states.
# Couldn't decorate mp-1080709 with oxidation states.
# Couldn't decorate mp-23300 with oxidation states.
# Couldn't decorate mp-1080485 with oxidation states.
# Couldn't decorate mp-2186 with oxidation states.
# Couldn't decorate mp-22912 with oxidation states.
# Couldn't decorate mp-2546 with oxidation states.
# Couldn't decorate mp-2596 with oxidation states.
# Couldn't decorate mp-6927 with oxidation states.
# Couldn't decorate mp-10108 with oxidation states.
# Couldn't decorate mp-10109 with oxidation states.
# Couldn't decorate mp-20969 with oxidation states.
# Couldn't decorate mp-627 with oxidation states.
# Couldn't decorate mp-807 with oxidation states.
# Couldn't decorate mp-15694 with oxidation states.
# Couldn't decorate mp-567580 with oxidation states.
# Couldn't decorate mp-1009545 with oxidation states.
# Couldn't decorate mp-2735 with oxidation states.
# Couldn't decorate mp-1018160 with oxidation states.
# Couldn't decorate mp-1079915 with oxidation states.
# Couldn't decorate mp-1078557 with oxidation states.
# Couldn't decorate mp-2548 with oxidation states.
# Couldn't decorate mp-2765 with oxidation states.
# Couldn't decorate mp-22879 with oxidation states.
# Couldn't decorate mp-280 with oxidation states.
# Couldn't decorate mp-1719 with oxidation states.
# Couldn't decorate mp-806 with oxidation states.
# Couldn't decorate mp-926 with oxidation states.
# Couldn't decorate mp-2086 with oxidation states.
# Couldn't decorate mp-2566 with oxidation states.
# Couldn't decorate mp-2288 with oxidation states.
# Couldn't decorate mp-1556 with oxidation states.
# Couldn't decorate mp-570632 with oxidation states.
# Couldn't decorate mp-1079811 with oxidation states.
# Couldn't decorate mp-22873 with oxidation states.
# Couldn't decorate mp-1025431 with oxidation states.
# Couldn't decorate mp-999133 with oxidation states.
# Couldn't decorate mp-22921 with oxidation states.
# Couldn't decorate mp-1080451 with oxidation states.
# Couldn't decorate mp-1079305 with oxidation states.
# Couldn't decorate mp-30838 with oxidation states.
# Couldn't decorate mp-503 with oxidation states.
# Couldn't decorate mp-1751 with oxidation states.
# Couldn't decorate mp-2183 with oxidation states.
# Couldn't decorate mp-998972 with oxidation states.
# Couldn't decorate mp-23234 with oxidation states.
# Couldn't decorate mp-1002114 with oxidation states.
# Couldn't decorate mp-1025448 with oxidation states.
# Couldn't decorate mp-1534 with oxidation states.
# Couldn't decorate mp-2637 with oxidation states.
# Couldn't decorate mp-1708 with oxidation states.
# Couldn't decorate mp-1084808 with oxidation states.
# Couldn't decorate mp-1025513 with oxidation states.
# Couldn't decorate mp-284 with oxidation states.
# Couldn't decorate mp-2658 with oxidation states.
# Couldn't decorate mp-1885 with oxidation states.
# Couldn't decorate mp-1487 with oxidation states.
# Couldn't decorate mp-875 with oxidation states.
# Couldn't decorate mp-10908 with oxidation states.
# Couldn't decorate mp-364 with oxidation states.
# Couldn't decorate mp-542569 with oxidation states.
# Couldn't decorate mp-11840 with oxidation states.
# Couldn't decorate mp-570775 with oxidation states.
# Couldn't decorate mp-527 with oxidation states.
# Couldn't decorate mp-2197 with oxidation states.
# Couldn't decorate mp-31509 with oxidation states.
# Couldn't decorate mp-902 with oxidation states.
# Couldn't decorate mp-2773 with oxidation states.
# Couldn't decorate mp-2323 with oxidation states.
# Couldn't decorate mp-1033 with oxidation states.
# Couldn't decorate mp-11274 with oxidation states.
# Couldn't decorate mp-11276 with oxidation states.
# Couldn't decorate mp-1073 with oxidation states.
# Couldn't decorate mp-11286 with oxidation states.
# Couldn't decorate mp-20263 with oxidation states.
# Couldn't decorate mp-1059707 with oxidation states.
# Couldn't decorate mp-20034 with oxidation states.
# Couldn't decorate mp-213 with oxidation states.
# Couldn't decorate mp-2861 with oxidation states.
# Couldn't decorate mp-2642 with oxidation states.
# Couldn't decorate mp-1404 with oxidation states.
# Couldn't decorate mp-1696 with oxidation states.
# Couldn't decorate mp-1194 with oxidation states.
# Couldn't decorate mp-1025468 with oxidation states.
# Couldn't decorate mp-11291 with oxidation states.
# Couldn't decorate mp-702 with oxidation states.
# Couldn't decorate mp-1062 with oxidation states.
# Couldn't decorate mp-986 with oxidation states.
# Couldn't decorate mp-1059242 with oxidation states.
# Couldn't decorate mp-1006884 with oxidation states.
# Couldn't decorate mp-1006883 with oxidation states.
# Couldn't decorate mp-1007819 with oxidation states.
# Couldn't decorate mp-1010071 with oxidation states.
# Couldn't decorate mp-2667 with oxidation states.
# Couldn't decorate mp-522 with oxidation states.
# Couldn't decorate mp-1018029 with oxidation states.
# Couldn't decorate mp-2167 with oxidation states.
# Couldn't decorate mp-770 with oxidation states.
# Couldn't decorate mp-2334 with oxidation states.
# Couldn't decorate mp-2443 with oxidation states.
# Couldn't decorate mp-257 with oxidation states.
# Couldn't decorate mp-2077 with oxidation states.
# Couldn't decorate mp-2738 with oxidation states.
# Couldn't decorate mp-2226 with oxidation states.
# Couldn't decorate mp-1078613 with oxidation states.
# Couldn't decorate mp-232 with oxidation states.
# Couldn't decorate mp-20379 with oxidation states.
# Couldn't decorate mp-11374 with oxidation states.
# Couldn't decorate mp-2303 with oxidation states.
# Couldn't decorate mp-2621 with oxidation states.
# Couldn't decorate mp-867 with oxidation states.
# Couldn't decorate mp-1955 with oxidation states.
# Couldn't decorate mp-2468 with oxidation states.
# Couldn't decorate mp-11370 with oxidation states.
# Couldn't decorate mp-2713 with oxidation states.
# Couldn't decorate mp-2228 with oxidation states.
# Couldn't decorate mp-567314 with oxidation states.
# Couldn't decorate mp-851 with oxidation states.
# Couldn't decorate mp-1025444 with oxidation states.
# Couldn't decorate mp-2381 with oxidation states.
# Couldn't decorate mp-1054 with oxidation states.
# Couldn't decorate mp-1660 with oxidation states.
# Couldn't decorate mp-1078589 with oxidation states.
# Couldn't decorate mp-580236 with oxidation states.
# Couldn't decorate mp-1087547 with oxidation states.
# Couldn't decorate mp-11375 with oxidation states.
# Couldn't decorate mp-1058490 with oxidation states.
# Couldn't decorate mp-21253 with oxidation states.
# Couldn't decorate mp-20394 with oxidation states.
# Couldn't decorate mp-542584 with oxidation states.
# Couldn't decorate mp-1261 with oxidation states.
# Couldn't decorate mp-2090 with oxidation states.
# Couldn't decorate mp-1918 with oxidation states.
# Couldn't decorate mp-11478 with oxidation states.
# Couldn't decorate mp-1121 with oxidation states.
# Couldn't decorate mp-11388 with oxidation states.
# Couldn't decorate mp-1941 with oxidation states.
# Couldn't decorate mp-2444 with oxidation states.
# Couldn't decorate mp-22320 with oxidation states.
# Couldn't decorate mp-542779 with oxidation states.
# Couldn't decorate mp-635426 with oxidation states.
# Couldn't decorate mp-1031 with oxidation states.
# Couldn't decorate mp-614455 with oxidation states.
# Couldn't decorate mp-11422 with oxidation states.
# Couldn't decorate mp-19819 with oxidation states.
# Couldn't decorate mp-2636 with oxidation states.
# Couldn't decorate mp-11428 with oxidation states.
# Couldn't decorate mp-1742 with oxidation states.
# Couldn't decorate mp-19966 with oxidation states.
# Couldn't decorate mp-2497 with oxidation states.
# Couldn't decorate mp-2027 with oxidation states.
# Couldn't decorate mp-11452 with oxidation states.
# Couldn't decorate mp-11457 with oxidation states.
# Couldn't decorate mp-2802 with oxidation states.
# Couldn't decorate mp-11460 with oxidation states.
# Couldn't decorate mp-2685 with oxidation states.
# Couldn't decorate mp-2778 with oxidation states.
# Couldn't decorate mp-170 with oxidation states.
# Couldn't decorate mp-1971 with oxidation states.
# Couldn't decorate mp-1092 with oxidation states.
# Couldn't decorate mp-30728 with oxidation states.
# Couldn't decorate mp-11476 with oxidation states.
# Couldn't decorate mp-1199 with oxidation states.
# Couldn't decorate mp-11871 with oxidation states.
# Couldn't decorate mp-1087502 with oxidation states.
# Couldn't decorate mp-1079180 with oxidation states.
# Couldn't decorate mp-2163 with oxidation states.
# Couldn't decorate mp-1540 with oxidation states.
# Couldn't decorate mp-2249 with oxidation states.
# Couldn't decorate mp-1009018 with oxidation states.
# Couldn't decorate mp-21215 with oxidation states.
# Couldn't decorate mp-899 with oxidation states.
# Couldn't decorate mp-30744 with oxidation states.
# Couldn't decorate mp-1948 with oxidation states.
# Couldn't decorate mp-776 with oxidation states.
# Couldn't decorate mp-1078920 with oxidation states.
# Couldn't decorate mp-734 with oxidation states.
# Couldn't decorate mp-20582 with oxidation states.
# Couldn't decorate mp-1104 with oxidation states.
# Couldn't decorate mp-11488 with oxidation states.
# Couldn't decorate mp-2615 with oxidation states.
# Couldn't decorate mp-2426 with oxidation states.
# Couldn't decorate mp-22902 with oxidation states.
# Couldn't decorate mp-2012 with oxidation states.
# Couldn't decorate mp-2314 with oxidation states.
# Couldn't decorate mp-569073 with oxidation states.
# Couldn't decorate mp-934 with oxidation states.
# Couldn't decorate mp-11249 with oxidation states.
# Couldn't decorate mp-2217 with oxidation states.
# Couldn't decorate mp-2522 with oxidation states.
# Couldn't decorate mp-1529 with oxidation states.
# Couldn't decorate mp-2195 with oxidation states.
# Couldn't decorate mp-1078899 with oxidation states.
# Couldn't decorate mp-2205 with oxidation states.
# Couldn't decorate mp-1025438 with oxidation states.
# Couldn't decorate mp-377 with oxidation states.
# Couldn't decorate mp-11495 with oxidation states.
# Couldn't decorate mp-11496 with oxidation states.
# Couldn't decorate mp-2696 with oxidation states.
# Couldn't decorate mp-437 with oxidation states.
# Couldn't decorate mp-11307 with oxidation states.
# Couldn't decorate mp-1408 with oxidation states.
# Couldn't decorate mp-1010953 with oxidation states.
# Couldn't decorate mp-506 with oxidation states.
# Couldn't decorate mp-1172 with oxidation states.
# Couldn't decorate mp-1174 with oxidation states.
# Couldn't decorate mp-11498 with oxidation states.
# Couldn't decorate mp-771 with oxidation states.
# Couldn't decorate mp-12675 with oxidation states.
# Couldn't decorate mp-1009133 with oxidation states.
# Couldn't decorate mp-2222 with oxidation states.
# Couldn't decorate mp-11500 with oxidation states.
# Couldn't decorate mp-238 with oxidation states.
# Couldn't decorate mp-1670 with oxidation states.
# Couldn't decorate mp-417 with oxidation states.
# Couldn't decorate mp-1009206 with oxidation states.
# Couldn't decorate mp-316 with oxidation states.
# Couldn't decorate mp-11503 with oxidation states.
# Couldn't decorate mp-11481 with oxidation states.
# Couldn't decorate mp-999502 with oxidation states.
# Couldn't decorate mp-12595 with oxidation states.
# Couldn't decorate mp-255 with oxidation states.
# Couldn't decorate mp-1009264 with oxidation states.
# Couldn't decorate mp-999376 with oxidation states.
# Couldn't decorate mp-432 with oxidation states.
# Couldn't decorate mp-1236 with oxidation states.
# Couldn't decorate mp-1080709 with oxidation states.
# Couldn't decorate mp-1059 with oxidation states.
# Couldn't decorate mp-13392 with oxidation states.
# Couldn't decorate mp-11467 with oxidation states.
# Couldn't decorate mp-1327 with oxidation states.
# Couldn't decorate mp-1080485 with oxidation states.
# Couldn't decorate mp-571405 with oxidation states.
# Couldn't decorate mp-1053 with oxidation states.
# Couldn't decorate mp-1057320 with oxidation states.
# Couldn't decorate mp-569593 with oxidation states.
# Couldn't decorate mp-2525 with oxidation states.
# Couldn't decorate mp-1079915 with oxidation states.
# Couldn't decorate mp-646 with oxidation states.
# Couldn't decorate mp-1079091 with oxidation states.
# Couldn't decorate mp-11469 with oxidation states.
# Couldn't decorate mp-20023 with oxidation states.
# Couldn't decorate mp-1548 with oxidation states.
# Couldn't decorate mp-1078557 with oxidation states.
# Couldn't decorate mp-12599 with oxidation states.
# Couldn't decorate mp-460 with oxidation states.
# Couldn't decorate mp-11555 with oxidation states.
# Couldn't decorate mp-30373 with oxidation states.
# Couldn't decorate mp-11237 with oxidation states.
# Couldn't decorate mp-331 with oxidation states.
# Couldn't decorate mp-11256 with oxidation states.
# Couldn't decorate mp-1211 with oxidation states.
# Couldn't decorate mp-2212 with oxidation states.
# Couldn't decorate mp-1169 with oxidation states.
# Couldn't decorate mp-11471 with oxidation states.
# Couldn't decorate mp-1129 with oxidation states.
# Couldn't decorate mp-11521 with oxidation states.
# Couldn't decorate mp-2781 with oxidation states.
# Couldn't decorate mp-892 with oxidation states.
# Couldn't decorate mp-1780 with oxidation states.
# Couldn't decorate mp-30867 with oxidation states.
# Couldn't decorate mp-11566 with oxidation states.
# Couldn't decorate mp-2475 with oxidation states.
# Couldn't decorate mp-1079811 with oxidation states.
# Couldn't decorate mp-572 with oxidation states.
# Couldn't decorate mp-980769 with oxidation states.
# Couldn't decorate mp-20298 with oxidation states.
# Couldn't decorate mp-2558 with oxidation states.
# Couldn't decorate mp-1025431 with oxidation states.
# Couldn't decorate mp-436 with oxidation states.
# Couldn't decorate mp-2541 with oxidation states.
# Couldn't decorate mp-2165 with oxidation states.
# Couldn't decorate mp-30496 with oxidation states.
# Couldn't decorate mp-542 with oxidation states.
# Couldn't decorate mp-2564 with oxidation states.
# Couldn't decorate mp-2434 with oxidation states.
# Couldn't decorate mp-1009826 with oxidation states.
# Couldn't decorate mp-1601 with oxidation states.
# Couldn't decorate mp-11572 with oxidation states.
# Couldn't decorate mp-2268 with oxidation states.
# Couldn't decorate mp-721 with oxidation states.
# Couldn't decorate mp-1837 with oxidation states.
# Couldn't decorate mp-2054 with oxidation states.
# Couldn't decorate mp-1635 with oxidation states.
# Couldn't decorate mp-1080451 with oxidation states.
# Couldn't decorate mp-1079305 with oxidation states.
# Couldn't decorate mp-11561 with oxidation states.
# Couldn't decorate mp-30878 with oxidation states.
# Couldn't decorate mp-836 with oxidation states.
# Couldn't decorate mp-30468 with oxidation states.
# Couldn't decorate mp-30838 with oxidation states.
# Couldn't decorate mp-1921 with oxidation states.
# Couldn't decorate mp-11279 with oxidation states.
# Couldn't decorate mp-823 with oxidation states.
# Couldn't decorate mp-305 with oxidation states.
# Couldn't decorate mp-1235 with oxidation states.
# Couldn't decorate mp-291 with oxidation states.
# Couldn't decorate mp-979261 with oxidation states.
# Couldn't decorate mp-998949 with oxidation states.
# Couldn't decorate mp-2179 with oxidation states.
# Couldn't decorate mp-2583 with oxidation states.
# Couldn't decorate mp-592 with oxidation states.
# Couldn't decorate mp-11573 with oxidation states.
# Couldn't decorate mp-11473 with oxidation states.
# Couldn't decorate mp-2796 with oxidation states.
# Couldn't decorate mp-2502 with oxidation states.
# Couldn't decorate mp-985 with oxidation states.
# Couldn't decorate mp-11475 with oxidation states.
# Couldn't decorate mp-20848 with oxidation states.
# Couldn't decorate mp-11483 with oxidation states.
# Couldn't decorate mp-1505 with oxidation states.
# Couldn't decorate mp-11525 with oxidation states.
# Couldn't decorate mp-348 with oxidation states.
# Couldn't decorate mp-11564 with oxidation states.
# Couldn't decorate mp-515 with oxidation states.
# Couldn't decorate mp-2316 with oxidation states.
# Couldn't decorate mp-1080107 with oxidation states.
# Couldn't decorate mp-1002109 with oxidation states.
# Couldn't decorate mp-1335 with oxidation states.
# Couldn't decorate mp-12778 with oxidation states.
# Couldn't decorate mp-1395 with oxidation states.
# Couldn't decorate mp-2540 with oxidation states.
# Couldn't decorate mp-2474 with oxidation states.
# Couldn't decorate mp-915 with oxidation states.
# Couldn't decorate mp-1080443 with oxidation states.
# Couldn't decorate mp-2399 with oxidation states.
# Couldn't decorate mp-22704 with oxidation states.
# Couldn't decorate mp-30746 with oxidation states.
# Couldn't decorate mp-615 with oxidation states.
# Couldn't decorate mp-1364 with oxidation states.
# Couldn't decorate mp-1025448 with oxidation states.
# Couldn't decorate mp-191 with oxidation states.
# Couldn't decorate mp-999484 with oxidation states.
# Couldn't decorate mp-11575 with oxidation states.
# Couldn't decorate mp-2516 with oxidation states.
# Couldn't decorate mp-2266 with oxidation states.
# Couldn't decorate mp-1084808 with oxidation states.
# Couldn't decorate mp-1857 with oxidation states.
# Couldn't decorate mp-1937 with oxidation states.
# Couldn't decorate mp-396 with oxidation states.
# Couldn't decorate mp-2545 with oxidation states.
# Couldn't decorate mp-2459 with oxidation states.
# Couldn't decorate mp-568705 with oxidation states.
# Couldn't decorate mp-2673 with oxidation states.
# Couldn't decorate mp-2547 with oxidation states.
# Couldn't decorate mp-570180 with oxidation states.
# Couldn't decorate mp-567089 with oxidation states.
# Couldn't decorate mp-567116 with oxidation states.
# Couldn't decorate mp-2806 with oxidation states.
# Couldn't decorate mp-11576 with oxidation states.
# Couldn't decorate mp-1703 with oxidation states.
# Couldn't decorate mp-1912 with oxidation states.
# Couldn't decorate mp-1684 with oxidation states.
# Couldn't decorate mp-987 with oxidation states.
# Couldn't decorate mp-429 with oxidation states.
# Couldn't decorate mp-1652 with oxidation states.
# Couldn't decorate mp-894 with oxidation states.
# Couldn't decorate mp-6938 with oxidation states.
# Couldn't decorate mp-2283 with oxidation states.
# Couldn't decorate mp-11541 with oxidation states.
# Couldn't decorate mp-669917 with oxidation states.
# Couldn't decorate mp-214 with oxidation states.
# Couldn't decorate mp-570276 with oxidation states.
# Couldn't decorate mp-1018126 with oxidation states.
# Couldn't decorate mp-1009540 with oxidation states.
# Couldn't decorate mp-999317 with oxidation states.
# Couldn't decorate mp-1018164 with oxidation states.
# Couldn't decorate mp-13174 with oxidation states.
# Couldn't decorate mp-1009747 with oxidation states.
# Couldn't decorate mp-1009813 with oxidation states.
# Couldn't decorate mp-1009848 with oxidation states.
# Couldn't decorate mp-999485 with oxidation states.
# Couldn't decorate mp-1064405 with oxidation states.

# %%
DB.add_structs(structs, "Experimental")
# Out:
# 295

# %%
fitted_df['spacegroup.crystal_system'].value_counts()
# Out:
# cubic           568
# orthorhombic     71
# tetragonal       32
# hexagonal        13
# trigonal          3
# monoclinic        3
# Name: spacegroup.crystal_system, dtype: int64

# %%
#function to return cation oxidation state
def cat_os(x):
    comp = Composition(x)
    os = comp.oxi_state_guesses()
    if len(os) > 0:
        oxidation_states = list(os[0].values())
    else:
        oxidation_states = [0,0]

    return oxidation_states[0]

#function to return anion oxidation state

def an_os(x):
    comp = Composition(x)
    os = comp.oxi_state_guesses()
    if len(os) > 0:
        oxidation_states = list(os[0].values())
    else:
        oxidation_states = [0,0]

    return oxidation_states[1]

# %%
fitted_df['cation_oxidation_state'] = fitted_df['pretty_formula'].apply(cat_os)
fitted_df['anion_oxidation_state'] = fitted_df['pretty_formula'].apply(an_os)
fitted_df
# Out:
#     pretty_formula material_id spacegroup.symbol spacegroup.crystal_system  \
# 0             AgBr    mp-23231             Fm-3m                     cubic
# 1              AgC  mp-1008653             Fm-3m                     cubic
# 2             AgCl    mp-22922             Fm-3m                     cubic
# 3              AgF     mp-7592             Fm-3m                     cubic
# 4              AgN  mp-1056955             Fm-3m                     cubic
# ..             ...         ...               ...                       ...
# 685           MgTe     mp-1039            P6_3mc                 hexagonal
# 686           MnSe   mp-999540            P6_3mc                 hexagonal
# 687            TlN  mp-1017982            P6_3mc                 hexagonal
# 688           ZnBi  mp-1064405            P6_3mc                 hexagonal
# 689            ZnO     mp-2133            P6_3mc                 hexagonal
#
#                                               icsd_ids  e_above_hull  \
# 0    [56548, 56547, 65061, 53850, 56546, 52246, 650...      0.037294
# 1                                             [183175]      2.235510
# 2                 [56540, 56539, 157535, 56538, 64734]      0.000000
# 3                                              [18008]      0.000000
# 4                             [167858, 185555, 183195]      1.408179
# ..                                                 ...           ...
# 685                    [52363, 642882, 168348, 642883]      0.000000
# 686                                           [643594]      0.000000
# 687                                   [644794, 186556]      0.721442
# 688                                           [100115]      0.242919
# 689  [193696, 195802, 31060, 166353, 166356, 154488...      0.000000
#
#      band_gap                                          structure  \
# 0      0.7946   [[0. 0. 0.] Ag, [2.925814 2.925814 2.925814] Br]
# 1      0.0000    [[0. 0. 0.] Ag, [2.333879 2.333879 2.333879] C]
# 2      1.2003   [[0. 0. 0.] Ag, [2.811198 2.811198 2.811198] Cl]
# 3      0.0000    [[0. 0. 0.] Ag, [2.514648 2.514648 2.514648] F]
# 4      0.0000       [[0. 0. 0.] Ag, [2.30808 2.30808 2.30808] N]
# ..        ...                                                ...
# 685    2.3620  [[2.30544    1.33104933 7.48602835] Mg, [ 2.30...
# 686    0.0000  [[ 2.102293   -1.21376176  3.41882115] Mn, [2....
# 687    0.0000  [[ 1.864724   -1.07660082  3.0409322 ] Tl, [1....
# 688    0.0000  [[2.353272   1.35866505 3.41544156] Zn, [ 2.35...
# 689    0.7316  [[ 1.644551   -0.94948423  2.65631864] Zn, [1....
#
#      cation_oxidation_state  anion_oxidation_state
# 0                       1.0                   -1.0
# 1                       2.0                   -2.0
# 2                       1.0                   -1.0
# 3                       1.0                   -1.0
# 4                       3.0                   -3.0
# ..                      ...                    ...
# 685                     2.0                   -2.0
# 686                     2.0                   -2.0
# 687                     3.0                   -3.0
# 688                     0.0                    0.0
# 689                     2.0                   -2.0
#
# [690 rows x 10 columns]

# %%
#dropping the compositions with no oxidation states (cation_oxidation_state = 0)
fitted_df = fitted_df[fitted_df.cation_oxidation_state != 0]
fitted_df = fitted_df.reset_index(drop=True)

# %%
#function to estimate coordination numbers
from pymatgen.analysis.local_env import CrystalNN


def co_ordination_num(y):
    structure = m.get_structure_by_material_id(y)
    crystal = CrystalNN()
    cn = crystal.get_cn(structure, 0)
    return cn


from tqdm import tqdm

tqdm.pandas()
fitted_df['coordination_number'] = fitted_df['material_id'].progress_apply(co_ordination_num)
# Out:
#   0%|                                                                                                                                                                                                                          | 0/290 [00:00<?, ?it/s]C:\Users\ashis\AppData\Local\Programs\Python\Python310\lib\site-packages\pymatgen\analysis\local_env.py:4121: UserWarning: No oxidation states specified on sites! For better results, set the site oxidation states in the structure.
#   warnings.warn(
# C:\Users\ashis\AppData\Local\Programs\Python\Python310\lib\site-packages\pymatgen\analysis\local_env.py:3924: UserWarning: CrystalNN: cannot locate an appropriate radius, covalent or atomic radii will be used, this can lead to non-optimal results.
#   warnings.warn(
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 290/290 [05:41<00:00,  1.18s/it]

# %%
#create a new dataframe for radius ratio rules
fitted_df_new = fitted_df.copy(deep=True)

#function to return radius ratio and corresponding coordination number and geometry
def radius_ratio(x):
    comp = Composition(x['pretty_formula'])
    elements = comp.chemical_system
    #split the individual elements in the system
    i_element = elements.partition('-')

    #create cation and anion species using smact
    cat = smact.Species(i_element[0], x['cation_oxidation_state'])
    an = smact.Species(i_element[2], x['anion_oxidation_state'])

    #calculate radius ratio
    rad_ratio = cat.average_ionic_radius/an.average_ionic_radius

    return rad_ratio

# %%
fitted_df_new['radius_ratio'] = fitted_df_new.dropna().apply(radius_ratio, axis=1)
fitted_df_new.head()
# Out:
#   pretty_formula material_id spacegroup.symbol spacegroup.crystal_system  \
# 0           AgBr    mp-23231             Fm-3m                     cubic
# 1            AgC  mp-1008653             Fm-3m                     cubic
# 2           AgCl    mp-22922             Fm-3m                     cubic
# 3            AgF     mp-7592             Fm-3m                     cubic
# 4            AgN  mp-1056955             Fm-3m                     cubic
#
#                                             icsd_ids  e_above_hull  band_gap  \
# 0  [56548, 56547, 65061, 53850, 56546, 52246, 650...      0.037294    0.7946
# 1                                           [183175]      2.235510    0.0000
# 2               [56540, 56539, 157535, 56538, 64734]      0.000000    1.2003
# 3                                            [18008]      0.000000    0.0000
# 4                           [167858, 185555, 183195]      1.408179    0.0000
#
#                                           structure  cation_oxidation_state  \
# 0  [[0. 0. 0.] Ag, [2.925814 2.925814 2.925814] Br]                     1.0
# 1   [[0. 0. 0.] Ag, [2.333879 2.333879 2.333879] C]                     2.0
# 2  [[0. 0. 0.] Ag, [2.811198 2.811198 2.811198] Cl]                     1.0
# 3   [[0. 0. 0.] Ag, [2.514648 2.514648 2.514648] F]                     1.0
# 4      [[0. 0. 0.] Ag, [2.30808 2.30808 2.30808] N]                     3.0
#
#    anion_oxidation_state  coordination_number  radius_ratio
# 0                   -1.0                    6      0.541545
# 1                   -2.0                    6           NaN
# 2                   -1.0                    6      0.586425
# 3                   -1.0                    6      0.812577
# 4                   -3.0                    6      0.486301
